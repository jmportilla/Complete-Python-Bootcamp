# %%
def init_cell():
    global cell
    cell = [' '] * 9

def print_board():
    print """%s|%s|%s\n-----\n%s|%s|%s\n-----\n%s|%s|%s\n""" % (cell[0],cell[1],cell[2],
                                                               cell[3],cell[4],cell[5],
                                                               cell[6],cell[7],cell[8])
print_board()
# Out:
#  | |
# -----
#  | |
# -----
#  | |

# %%
cell[1] = 'X'
print_board()
# Out:
#  |X|
# -----
#  | |
# -----
#  | |
